# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('C:/Users/ACER/Desktop/bitcoin-price-prediction/BTC-USD.csv')

# %%
df.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 1  2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2  2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 3  2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 4  2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#       Adj Close       Volume
# 0  11384.181641  19968627060
# 1  11384.181641  19968627060
# 2  11384.181641  19968627060
# 3  11429.506836  24103426719
# 4  11495.349609  24487233058

# %%
 df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count    366.000000    366.000000    366.000000    366.000000    366.000000
# mean   38642.440454  39837.545103  37359.313146  38762.324376  38762.324376
# std    14120.976742  14465.623174  13685.716910  14082.360612  14082.360612
# min    11296.082031  11386.261719  11223.012695  11322.123047  11322.123047
# 25%    31666.785644  32666.272461  30193.673340  31702.702636  31702.702636
# 50%    39210.443360  40554.923829  37442.914062  39237.388672  39237.388672
# 75%    49199.198243  50535.691406  47679.570313  49187.537110  49187.537110
# max    63523.753906  64863.097656  62208.964844  63503.457031  63503.457031
#
#              Volume
# count  3.660000e+02
# mean   4.742052e+10
# std    2.486763e+10
# min    1.828331e+10
# 25%    3.199627e+10
# 50%    4.240475e+10
# 75%    5.851956e+10
# max    3.509679e+11

# %%
df.dtypes
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df['Date'].dtype
# Out:
# dtype('<M8[ns]')

# %%
df = df.sort_index()

# %%
df.head()
# Out:
#         Date          Open          High           Low         Close  \
# 0 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 1 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 3 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 4 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#       Adj Close       Volume
# 0  11384.181641  19968627060
# 1  11384.181641  19968627060
# 2  11384.181641  19968627060
# 3  11429.506836  24103426719
# 4  11495.349609  24487233058

# %%
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#                Adj Close       Volume
# Date
# 2020-10-11  11384.181641  19968627060
# 2020-10-12  11384.181641  19968627060
# 2020-10-13  11384.181641  19968627060
# 2020-10-14  11429.506836  24103426719
# 2020-10-15  11495.349609  24487233058

# %%
data = df.copy()

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#                Adj Close       Volume
# Date
# 2020-10-11  11384.181641  19968627060
# 2020-10-12  11384.181641  19968627060
# 2020-10-13  11384.181641  19968627060
# 2020-10-14  11429.506836  24103426719
# 2020-10-15  11495.349609  24487233058

# %%
data['Close'].plot()
plt.ylabel('Bitcoin Price')
# Out:
# Text(0, 0.5, 'Bitcoin Price')

# %%
Closing = data['Close']

# %%
Closing.head()
# Out:
# Date
# 2020-10-11    11384.181641
# 2020-10-12    11384.181641
# 2020-10-13    11384.181641
# 2020-10-14    11429.506836
# 2020-10-15    11495.349609
# Name: Close, dtype: float64

# %%
Closing.resample('W').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Closing.resample('M').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Closing.resample('Y').sum().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Closing.resample('W').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
Closing.index.dayofweek
# Out:
# Int64Index([6, 0, 1, 2, 3, 4, 5, 6, 0, 1,
#             ...
#             5, 6, 0, 1, 2, 3, 4, 5, 6, 0],
#            dtype='int64', name='Date', length=366)

# %%
weekday =data.groupby(Closing.index.dayofweek)['Close'].mean()
weekday
# Out:
# Date
# 0    38667.176260
# 1    38287.772743
# 2    38669.505615
# 3    38731.982460
# 4    39094.161640
# 5    39197.654128
# 6    38691.215046
# Name: Close, dtype: float64

# %%
weekday.index = ['Mon','Tue','Wed','Thu','Fri','Sat','Sun']

# %%
weekday
# Out:
# Mon    38667.176260
# Tue    38287.772743
# Wed    38669.505615
# Thu    38731.982460
# Fri    39094.161640
# Sat    39197.654128
# Sun    38691.215046
# Name: Close, dtype: float64

# %%
weekday.plot()
# Out:
# <AxesSubplot:>

# %%
days = Closing.index.dayofyear

# %%
days
# Out:
# Int64Index([285, 286, 287, 288, 289, 290, 291, 292, 293, 294,
#             ...
#             275, 276, 277, 278, 279, 280, 281, 282, 283, 284],
#            dtype='int64', name='Date', length=366)

# %%
plt.figure(figsize=(10,8))
data.groupby(days)['Close'].mean().plot()
plt.ylabel('Average Closing Price')
# Out:
# Text(0, 0.5, 'Average Closing Price')

# %%
Closing.index.quarter
# Out:
# Int64Index([4, 4, 4, 4, 4, 4, 4, 4, 4, 4,
#             ...
#             4, 4, 4, 4, 4, 4, 4, 4, 4, 4],
#            dtype='int64', name='Date', length=366)

# %%
plt.figure(figsize=(10,8))
data.groupby(Closing.index.quarter)['Close'].plot()
plt.ylabel('Average Closing Price')
plt.legend()

# %%
data['dayofweek']= data.index.dayofweek

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#                Adj Close       Volume  dayofweek
# Date
# 2020-10-11  11384.181641  19968627060          6
# 2020-10-12  11384.181641  19968627060          0
# 2020-10-13  11384.181641  19968627060          1
# 2020-10-14  11429.506836  24103426719          2
# 2020-10-15  11495.349609  24487233058          3

# %%
def assign_labels(feature):
    if feature<5:
        return 'weekdays'
    else:
        return 'weekends'

# %%
data['dayofweek'].apply(assign_labels)
# Out:
# Date
# 2020-10-11    weekends
# 2020-10-12    weekdays
# 2020-10-13    weekdays
# 2020-10-14    weekdays
# 2020-10-15    weekdays
#                 ...
# 2021-10-07    weekdays
# 2021-10-08    weekdays
# 2021-10-09    weekends
# 2021-10-10    weekends
# 2021-10-11    weekdays
# Name: dayofweek, Length: 366, dtype: object

# %%
data['dayofweek']= data['dayofweek'].apply(assign_labels)

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#                Adj Close       Volume dayofweek
# Date
# 2020-10-11  11384.181641  19968627060  weekends
# 2020-10-12  11384.181641  19968627060  weekdays
# 2020-10-13  11384.181641  19968627060  weekdays
# 2020-10-14  11429.506836  24103426719  weekdays
# 2020-10-15  11495.349609  24487233058  weekdays

# %%
fig,ax=plt.subplots(1,2,figsize=(14,8))
data[data['dayofweek']=='weekends']['Close'].plot(ax=ax[0],title='weekends')
data[data['dayofweek']=='weekdays']['Close'].plot(ax=ax[1],title='weekdays')
# Out:
# <AxesSubplot:title={'center':'weekdays'}, xlabel='Date'>

# %%
data['prediction_naive']= data['Close'].shift(1)

# %%
data.head()
# Out:
#                     Open          High           Low         Close  \
# Date
# 2020-10-11  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-12  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-13  11296.082031  11428.813477  11288.627930  11384.181641
# 2020-10-14  11429.047852  11539.977539  11307.831055  11429.506836
# 2020-10-15  11426.602539  11569.914063  11303.603516  11495.349609
#
#                Adj Close       Volume dayofweek  prediction_naive
# Date
# 2020-10-11  11384.181641  19968627060  weekends               NaN
# 2020-10-12  11384.181641  19968627060  weekdays      11384.181641
# 2020-10-13  11384.181641  19968627060  weekdays      11384.181641
# 2020-10-14  11429.506836  24103426719  weekdays      11384.181641
# 2020-10-15  11495.349609  24487233058  weekdays      11429.506836

# %%
data[['Close','prediction_naive']].plot(figsize=(14,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
 from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(data['Close'][1:],data['prediction_naive'][1:]))
# Out:
# 1733.9502181744554
